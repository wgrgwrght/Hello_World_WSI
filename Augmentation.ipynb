# %% [markdown]
# <a href="https://colab.research.google.com/github/wgrgwrght/Hello_World_WSI/blob/main/Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import PIL
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
import os

print(sys.version)

py_file_location = "/content/drive"
sys.path.append(os.path.abspath(py_file_location))
# Out:
# 3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]

# %%
# Open training image
train_path = '/content/drive/MyDrive/Pannuke/test/images/Breast_fold3_180.png'
train_im = cv2.imread(train_path)

# %%
r = cv2.rotate(train_im, cv2.ROTATE_90_CLOCKWISE)
u = cv2.rotate(train_im, cv2.ROTATE_180)
l = cv2.rotate(train_im, cv2.ROTATE_90_COUNTERCLOCKWISE)

# %%
gray_dir = "/mnt/test.png"
r.save(gray_dir)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-852a3cb95cef> in <module>
#       1 gray_dir = "/mnt/test.png"
# ----> 2 r.save(gray_dir)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'

# %%
plt.imshow(train_im)
plt.show()
plt.imshow(r)
plt.show()
plt.imshow(u)
plt.show()
plt.imshow(l)
plt.show()
